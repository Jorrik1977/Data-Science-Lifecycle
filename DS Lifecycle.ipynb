# %% [markdown]
# ![what-is-data-science-1.jpg](attachment:what-is-data-science-1.jpg)

# %% [markdown]
# # Part 0: Ressources

# %% [markdown]
# timeframe
#
# money
#
# people
#
# energy

# %% [markdown]
# # Part 1: Business Understanding

# %% [markdown]
# **Domain Knowledge!**
#
# Problem statement: classification or regression, metric of success
#
# What is the business domain?
#
# What are business interests and potential benefits?
#
# Why do we care?
#
# What are relevant questions, which could be answered by Data Science?
#
# What insights can be gained, what are interesting questions?
#
# **HOW´s:**
#
# Looking/Understanding Data Dictionary
#
# Company website
#
# Competitors website
#
# Ask the stakeholders
#
# Google scholar/Research paper
#
# What have other Data Scientist done in the same Domain?

# %% [markdown]
# # Part 2: Data Mining

# %% [markdown]
# Webscraping
#
# SQL, Pyspark
#
# Given Dataset
#
# Change txt into csv
#
# Merge/Join datasets

# %% [markdown]
# # Part 3 and 4: EDA and Data Cleaning

# %% [markdown]
# **Explore Dataset**
#
# Is data loaded correctly?
#
# Size of the dataset: .shape
#
# If too small: synthesize data, imbalanced:upsampling
#
# If too large: random sample?, imbalanced:undersampling
#
# Multiple datasets? Join/merge, trunkate, modify
#
# What is the target variable? distribution: df.y.value_counts()
#
# Understanding observations/rows
#
# What are the feature variables? dtype
#
# Numerical or categorical variables?
#
# .describe(), .info(), .head(), .tail()
#
# Same scale of dtypes, naming conventions
#
# Check for inconsistencies: outlier
#
# Check for subsets/additional datasets
#
# Visualization of distributions: matplotlib, seaborn, bokeh, plotly, folium
#
#     Barplots, Histogram, ...
#
# Scatterplots of Target vs. some Features
#
# Plots of distribution of categorical Variables
#
# Heatmap as well
#
#
# **Cleaning**
#
# Missing values: what kind of? NaN, Value, empty, O (visualize: missingno)
#
# Delete Duplicates: same ID other data? double rows
#
# Replace fillna, ffill
#
# Column renaming
#
# Column/Feature dropping
#
# Row/Observation dropping
#
# Outliers, drop/replace
#
# Create Dummy for missing values (0=absent, 1=there)
#
# Data too small: look for similar data at other place, ask for more data, synthesize data
#
# Data too big: random samples (after EDA, cleaning)
#
# Multiple datasets: Merge/Join datasets, find relationships among them
#
# Change variable dtypes: Pandas: to numeric, string to datetime, timestamp

# %% [markdown]
# # Part 5: Feature Engineering

# %% [markdown]
# Transforming skewed continuous variables to more normally distributed values
#
# Normalise or standardise numerical features (MinMaxScaler, StandardScaler)
#
# PCA (Dimensionality reduction)
#
# Creating new Features (out of existing ones): extract gender
#
# Creating new categories: by regrouping, binning numericals
#
# Correlation (Scatterplot, Heatmap)
#
# Check Multicolinearity
#
# get_dummies for categorical variables
#
# Categoricals: Imbalanced Classes
#
#     can lead to poor classifiers (possibly many FP)
#
#     forcing balanced data
#
#         removing data from larger class
#
#         replicate data from smaller class
#
# Impute values for features (data cleaning also)
#
# Assign weights to features
#
# Drop not needed Features

# %% [markdown]
# # Part 6: Predictive Modelling

# %% [markdown]
# Train, test, split the data
#
# Pick right model to use
#
# Select Statistical Learning Models:
#
#     Regression: Linear, Multiple Linear, Polynomial
#
#     Lasso (Feature Selection), Ridge Regression, Elastic Net
#
#     Logistic Regression
#
#     KNN, k nearest neighbour
#
#     Naive Bayes
#
#     Decision Trees
#
#     Random Forests (Ensemble of many, small Decision Trees)
#
#     Ensemble Methods:
#
#         Bagging (reduce Variance)
#
#         Boosting (reduce Bias)
#
#         Stacking (Max Vote, Avg, Weighted Avg)
#
#     Support Vector Machine
#
# balancing the data
#
# baseline model
#
# Run the model: PCA, Kfold Crossvalidation
#
# train, predict modelling pipeline
#
# Model Evaluation (which is important for predetermined metric of success):
#
#     Test scores
#
#     Cross Validation (kFold, ...)
#
#     Evaluation metrics
#
#     Confusion matrix
#
#     Accuracy
#
#     Precision
#
#     Recall
#
#     Specificity
#
#     F-Score
#
#     ROC Curve
#
#     ROC AUC
#
# Model Tuning:
#
#     GridSearchCV
#
#     RandomizedSearchCV
#
# Final Model Evaluation
#
# Feature Importance (most important predictors)
#
# Visualize Feature Importance
#
# Hypothesis Testing for marketing/sales/healthcare

# %% [markdown]
# # Part 7: Data Visualisation

# %% [markdown]
# Technical:
#
#     Regarding target and features, domain space
#
#     Regarding model performance
#
# Business:
#
#     Make insightful and compelling visualisations
#
#     Regarding domain specific business questions
